# %% [markdown]
# # Google colab tutorial
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# #### 저희는 교육기간 실습 시간에 colab을 활용하여 실습을 진행할 예정입니다!
# #### 아래 다섯가지 과정만 잘 숙지해주신다면, 실습을 진행하는 것에 있어서 크게 어려움이 없을 것이라고 생각합니다.

# %% [markdown]
# ## 1. 구글 계정 및 구글 드라이브 세팅하기
#
# #### '내 드라이브' 안에 코랩 코드 저장 목적용으로 폴더를 하나 만들어 주세요. 예를 들어 'colab_folder' 처럼 만들어주시면 됩니다.

# %%
print('hi')
# Out:
# hi

# %%
a = 43
print(f'a is {a}')
# Out:
# a is 43

# %% [markdown]
# ## 2. GPU 설정하기
#
# Runtime => Change runtime type => Hardware accelerator에서 'GPU' 선택

# %% [markdown]
# ## 3. 개인 계정의 구글 드라이브 마운트

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/과외/수업/1.0801_Colab_setting')
# Out:
# ['01_colab_tutorial.ipynb', 'DATA', 'colab_Introduction.pdf']

# %%
with open('/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATA/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')

# %% [markdown]
# ## numpy

# %% [markdown]
# - 이제부터 넘파이 실행하겠다.
# - 텍스트 셀에 대해 이렇게 사용

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
np.save('/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATA/ppssbb09.npy', a)

# %%
b = np.load('/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATA/ppssbb09.npy')

# %%
print(b)
# Out:
# [1 2 3]

# %%
DATA_DIR = "/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATA"
CSV_FILE = DATA_DIR + "ppssbb09.npy"
CSV_FILE
# Out:
# '/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATAppssbb09.npy'

# %%
CSV_FILE_ver_2 = os.path.join(DATA_DIR,'DATA',"ppssbb09.npy")
CSV_FILE_ver_2
# Out:
# '/content/drive/MyDrive/과외/수업/1.0801_Colab_setting/DATA/DATA/ppssbb09.npy'

# %% [markdown]
# ## 4. 로컬 파일 업로드

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fdb54c1-6873-49ba-9d2e-54f33e624f35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fdb54c1-6873-49ba-9d2e-54f33e624f35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 5. python library 설치

# %%
import numpy as np

# %%
import cartopy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-a4ba129e3112> in <cell line: 1>()
# ----> 1 import cartopy
#
# ModuleNotFoundError: No module named 'cartopy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To install cartopy, click the button below.
# ---------------------------------------------------------------------------

# %%
# !pip install cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 38.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.4 MB/s eta 0:00:00
# ...
#   Created wheel for cartopy: filename=Cartopy-0.21.1-cp310-cp310-linux_x86_64.whl size=11080588 sha256=bb7f487adb8a7cf64cf56a88b84d11afa32dbc2868f87e91cd5e2026f8f1e3a5
#   Stored in directory: /root/.cache/pip/wheels/30/b0/1a/1c1909e00c76653dc4e2ff48555257c0eb2d1698280c8d9955
# Successfully built cartopy
# ...

# %%
import cartopy

# %% [markdown]
# ## 6. 기타 커멘드

# %% [markdown]
# - 셀 10개 만들기
# - 만든셀 중 5개를 text cell로 수정하기
# - Markdown 편집기 이용하기

# %%
# pd.read_csv =
# pd.read_csv =
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
# pd.read_csv
